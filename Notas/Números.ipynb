# %% [markdown]
# # Operações Básicas

# %% [markdown]
# # Números Complexos

# %%
#Converter números em números complexos:
x = 5
print(x)
x = complex(x)
print(x)
print(type(x))
# Out:
# 5
# (5+0j)
# <class 'complex'>

# %%
y = 5+2j

print(type(y))
# Out:
# <class 'complex'>
